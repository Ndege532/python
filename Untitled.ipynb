# %%
import math as math;
import matplotlib as mp;
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;

# %%
print ("hello world am now fully into python")
# Out:
# hello world am now fully into python

# %%
print (1+2)
# Out:
# 3

# %%
print (3*3)
# Out:
# 9

# %%
#read the csv file 
df = pd.read_csv ("C:\Users\ndege\Downloads\survey.csv")
# Out:
#   File "<ipython-input-5-a7adb3e055d6>", line 2
#     df = pd.read_csv ("C:\Users\ndege\Downloads\survey.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print (df)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# 5      2018                     Level 1                99999
# 6      2018                     Level 1                99999
# 7      2018                     Level 1                99999
# 8      2018                     Level 1                99999
# 9      2018                     Level 1                99999
# 10     2018                     Level 1                99999
# 11     2018                     Level 1                99999
# 12     2018                     Level 1                99999
# 13     2018                     Level 1                99999
# ...

# %%
df.sort_values(["Industry_code_ANZSIC06", "Year"], axis=0, 
                 ascending=True, inplace=True)

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 25430  2013                     Level 4                FF116
# 25431  2013                     Level 4                FF116
# 25432  2013                     Level 4                FF116
# 25433  2013                     Level 4                FF116
# 25434  2013                     Level 4                FF116
# 25435  2013                     Level 4                FF116
# 25436  2013                     Level 4                FF116
# 25437  2013                     Level 4                FF116
# 25438  2013                     Level 4                FF116
# 25439  2013                     Level 4                FF116
# 25440  2013                     Level 4                FF116
# 25441  2013                     Level 4                FF116
# 25442  2013                     Level 4                FF116
# 25443  2013                     Level 4                FF116
# ...

# %%
df. head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-79b2415647c8> in <module>
# ----> 1 df. head()
#
# NameError: name 'df' is not defined
